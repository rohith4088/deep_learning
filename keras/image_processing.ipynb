# %%
import keras_cv
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import keras_cv
#       2 import tensorflow
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/keras_cv/__init__.py:27
#      24 # isort:off
#      25 from keras_cv import version_check
# ---> 27 version_check.check_tf_version()
#      28 # isort:on
#      30 from keras_cv import bounding_box
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/keras_cv/version_check.py:25, in check_tf_version()
#      24 def check_tf_version():
# ---> 25     if parse(tf.__version__) < parse(MIN_VERSION):
#      26         raise RuntimeError(
#      27             "The Tensorflow package version needs to be at least "
#      28             f"{MIN_VERSION} for KerasCV to run. Currently, your TensorFlow "
#    (...)
#      31             "afterwards that everything is ok."
#      32         )
#
# ...

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow
# ----> 2 print(tensorflow.__version__)
#
# AttributeError: module 'tensorflow' has no attribute '__version__'

# %%
import keras
print(keras.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import keras
#       2 print(keras.__version__)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/keras/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/keras/__internal__/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/keras/__internal__/backend/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
# ...

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import tensorflow
# ----> 2 print(tensorflow.__version__)
#
# AttributeError: module 'tensorflow' has no attribute '__version__'
